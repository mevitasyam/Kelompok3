# %% [markdown]
# <a href="https://colab.research.google.com/github/mevitasyam/Kelompok3/blob/main/Prediksi_Nilai_(Modelling).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploring Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/student-mat.csv")
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences PreTest Test PostTest
# 0      4        3      4     1     1      3        6       5    6        6
# 1      5        3      3     1     1      3        4       5    5        6
# 2      4        3      2     2     3      3       10       7    8       10
# 3      3        2      2     1     1      5        2      15   14       15
# 4      4        3      2     1     2      5        4       6   10       10
#
# [5 rows x 33 columns]

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
#mencari missing value
data.isnull().sum().any()
# Out:
# False

# %%
sc_gp = data[data['school']=='GP']['PostTest'].value_counts()
sc_ms = data[data['school']=='MS']['PostTest'].value_counts()
sc_df = pd.DataFrame([sc_gp, sc_ms], index=['School GP', 'School MS'])
sc_df = sc_df.T

# %%
# Menampilkan data melalui grafik dari setiap sekolah
sns.lineplot(data=sc_df)

# %%
# Menampilkan diagram chart data dengan pendistribusian terhadap kolom

fg, axs = plt.subplots(1, 2, figsize=(10,5))

axs[0].set_title('Distribution of Age & Sex wrt Score PostTest')
sns.barplot(x='age', y='PostTest', hue='sex', data=data, ax=axs[0])

axs[1].set_title('Distribution of count of Age & Sex')
sns.countplot(x='age', hue='sex', data=data, ax=axs[1])

# %%
# Menampilkan data melalui korelasi dari Fam_edu dan nilai post test

fam_edu = data['Fedu'] + data['Medu']
sns.swarmplot(x=fam_edu, y='PostTest', data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Menampilkan data dengan korelasi dari study time, travel time dengan nilai post test

fg, axs = plt.subplots(1, 2, figsize=(10,5))

axs[0].set_title('Travel time wrt Score PostTest')
sns.swarmplot(x='traveltime', y='PostTest', data=data, ax=axs[0])

axs[1].set_title('Study time wrt Score PostTest')
sns.swarmplot(x='studytime', y='PostTest', data=data, ax=axs[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 42.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fg, axs = plt.subplots(3,3, figsize=(20,15))

axs[0,0].set_title('School Support vs PostTest')
sns.swarmplot(x='schoolsup', y='PostTest', data=data, ax=axs[0,0])
axs[0,0].set_xlabel('School Support')

axs[0,1].set_title('Family Support vs PostTest')
sns.swarmplot(x='famsup', y='PostTest', data=data, ax=axs[0,1])
axs[0,1].set_xlabel('Family Support')

axs[0,2].set_title('Paid for extra class vs PostTest')
sns.swarmplot(x='paid', y='PostTest', data=data, ax=axs[0,2])
axs[0,2].set_xlabel('Extra paid')

axs[1,0].set_title('Extra-curricular activities vs PostTest')
sns.swarmplot(x='activities', y='PostTest', data=data, ax=axs[1,0])
axs[1,0].set_xlabel('Extra-curricular activities')

axs[1,1].set_title('Nursery vs PostTest')
sns.swarmplot(x='nursery', y='PostTest', data=data, ax=axs[1,1])
axs[1,1].set_xlabel('Nursery')

axs[1,2].set_title('Higher Education vs PostTest')
sns.swarmplot(x='higher', y='PostTest', data=data, ax=axs[1,2])
axs[1,2].set_xlabel('Higher Education')

axs[2,0].set_title('Internet Access vs PostTest')
sns.swarmplot(x='internet', y='PostTest', data=data, ax=axs[2,0])
axs[2,0].set_xlabel('Internet Access')

axs[2,1].set_title('Romantic Relation vs PostTest')
sns.swarmplot(x='romantic', y='PostTest', data=data, ax=axs[2,1])
axs[2,1].set_xlabel('Romantic Relation')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 21.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
alc = data['Dalc'] + data['Walc']
sns.swarmplot(x=alc, y='PostTest', data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 52.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 25.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 15.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#menampilkan hasil pretest,test dan postest dalam bentuk grafik
fg, axs = plt.subplots(1, 3, figsize=(20, 5))
PreTest = sns.distplot(data['PreTest'], ax=axs[0])
MidTest = sns.distplot(data['Test'], ax=axs[1])
PostTest = sns.distplot(data['PostTest'], ax=axs[2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fg, axs = plt.subplots(2,2, figsize=(20,10))
b1 = sns.lineplot(x='PreTest', y='PostTest', data=data, ax=axs[0,0])
b2 = sns.scatterplot(x='PreTest', y='PostTest', data=data, ax=axs[0,1])
b3 = sns.lineplot(x='Test', y='PostTest', data=data, ax=axs[1,0])
b4 = sns.scatterplot(x='Test', y='PostTest', data=data, ax=axs[1,1])

# %%
sns.countplot(x='PostTest', data=data, order=data['PostTest'].value_counts().index)

# %% [markdown]
# # **Data Processing**

# %% [markdown]
# Labelling data

# %%
#Melakukan labeling dataset
#school
sch_map = {'GP':1, 'MS':2}
data['school'] = data['school'].map(sch_map)

#sex
sex_map = {'F':1, 'M':2}
data['sex'] = data['sex'].map(sex_map)

#address
fmap = {'U':1, 'R':2}
data['address'] = data['address'].map(fmap)

#famsize
fmap = {'LE3':1, 'GT3':2}
data['famsize'] = data['famsize'].map(fmap)

#Pstatus
fmap = {'T':1, 'A':2}
data['Pstatus'] = data['Pstatus'].map(fmap)

#Mjob and Fjob
fmap = {'services':1, 'at_home':2, 'teacher':3, 'health':4, 'other':5}
data['Mjob'] = data['Mjob'].map(fmap)
data['Fjob'] = data['Fjob'].map(fmap)

#reason
fmap = {'course':1, 'home':2, 'reputation':3, 'other':4}
data['reason'] = data['reason'].map(fmap)

#guardian
fmap = {'mother':1, 'father':2, 'other':3}
data['guardian'] = data['guardian'].map(fmap)

#schoolsup famsup paid
fmap = {'yes':1, 'no':0}
data['schoolsup'] = data['schoolsup'].map(fmap)
data['famsup'] = data['famsup'].map(fmap)
data['paid'] = data['paid'].map(fmap)
data['activities'] = data['activities'].map(fmap)
data['nursery'] = data['nursery'].map(fmap)
data['higher'] = data['higher'].map(fmap)
data['internet'] = data['internet'].map(fmap)
data['romantic'] = data['romantic'].map(fmap)

# %%
X = data.iloc[:, :32]
y = data.iloc[:, -1]

# %%
# Mencari K terbaik dengan menggunakan nilai chi

from sklearn.feature_selection import SelectKBest, chi2

k_best = SelectKBest(score_func=chi2, k=30)
k_best.fit(X, y)

df_score = pd.Series(data=k_best.scores_, index=X.columns)
df_score
# Out:
# school          1.075490
# sex             3.399950
# age             2.277762
# address         3.734921
# famsize         2.096131
# Pstatus         1.389328
# Medu           13.894852
# Fedu           10.375563
# Mjob           15.129472
# Fjob           19.952055
# reason         11.355722
# guardian        3.419273
# traveltime      6.758151
# studytime       6.231603
# failures      140.934898
# schoolsup      28.319018
# famsup          5.303438
# paid           16.129900
# activities      7.601049
# nursery         3.297083
# higher          1.234479
# internet        2.999142
# romantic       20.089526
# famrel          2.110686
# freetime        4.479465
# goout          10.472494
# Dalc           17.082868
# Walc           28.444167
# health         10.176668
# absences      648.166848
# PreTest       319.716427
# Test          451.680952
# dtype: float64

# %%
df_score.nlargest(30).plot(kind='bar')

# %%
#Hasil Matrix
plt.figure(figsize=(20, 10))
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# # **Modelling data**

# %%
#menampilkan 15 data tertinggi
data.corr()['PostTest'].nlargest(15)
# Out:
# PostTest     1.000000
# Test         0.904868
# PreTest      0.801468
# Medu         0.217147
# higher       0.182465
# Fedu         0.152457
# reason       0.120454
# sex          0.103456
# paid         0.101996
# internet     0.098483
# studytime    0.097820
# Pstatus      0.058009
# nursery      0.051568
# famrel       0.051363
# absences     0.034247
# Name: PostTest, dtype: float64

# %%
# Menampilkan beberapa data yang akan digunakan
dataset2 = pd.read_csv("/content/student-mat.csv")
dataset2 = dataset2[['PreTest','Test','PostTest','Medu','higher']]
dataset2
# Out:
#      PreTest  Test  PostTest  Medu higher
# 0          5     6         6     4    yes
# 1          5     5         6     1    yes
# 2          7     8        10     1    yes
# 3         15    14        15     4    yes
# 4          6    10        10     3    yes
# ..       ...   ...       ...   ...    ...
# 390        9     9         9     2    yes
# 391       14    16        16     3    yes
# 392       10     8         7     1    yes
# 393       11    12        10     3    yes
# 394        8     9         9     1    yes
#
# [395 rows x 5 columns]

# %%
X = data[df_score.nlargest(30).index]
y = data['PostTest']

# %%
# Mencari nilai data dengan persentase 70 30
from sklearn.model_selection import train_test_split, KFold, cross_val_score

k_fold = KFold(n_splits=10, random_state=10, shuffle=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((276, 30), (119, 30), (276,), (119,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

from sklearn.metrics import mean_squared_error

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,4))
sns.heatmap(data.isnull(),cbar=False,cmap='viridis',yticklabels=False)
plt.title('Missing value in the dataset');

# %%
import numpy as np
numeric_columns=data.loc[:, data.columns != 'PostTest'].select_dtypes(include=np.number).columns.tolist()

# %%
data.boxplot(column=numeric_columns,fontsize=10,rot=0,grid=False,figsize=(10,10),vert=False)

# %%
Q1 = data[numeric_columns].quantile(0.25)
Q3 = data[numeric_columns].quantile(0.75)
IQR = Q3 - Q1
boxplot_min = Q1 - 1.5 * IQR
boxplot_max = Q3 + 1.5 * IQR
print('Q1:\n',Q1)
print('\nQ3:\n',Q3)
print('\nIQR:\n',IQR)
print('\nMin:\n',boxplot_min)
print('\nMax:\n',boxplot_max)
# Out:
# Q1:
#  school         1.0
# sex            1.0
# age           16.0
# address        1.0
# famsize        1.0
# Pstatus        1.0
# Medu           2.0
# Fedu           2.0
# Mjob           1.0
# Fjob           1.0
# reason         1.0
# guardian       1.0
# traveltime     1.0
# studytime      1.0
# failures       0.0
# schoolsup      0.0
# famsup         0.0
# paid           0.0
# activities     0.0
# nursery        1.0
# higher         1.0
# internet       1.0
# romantic       0.0
# famrel         4.0
# freetime       3.0
# goout          2.0
# Dalc           1.0
# Walc           1.0
# health         3.0
# absences       0.0
# PreTest        8.0
# Test           9.0
# Name: 0.25, dtype: float64
#
# Q3:
#  school         1.0
# sex            2.0
# age           18.0
# address        1.0
# famsize        2.0
# Pstatus        1.0
# Medu           4.0
# Fedu           3.0
# Mjob           5.0
# Fjob           5.0
# reason         3.0
# guardian       2.0
# traveltime     2.0
# ...

# %%
non_outlier_data = data.copy()
for x in numeric_columns:
  filter_min = non_outlier_data[x]<boxplot_min[x]
  filter_max = non_outlier_data[x]>boxplot_max[x]
  non_outlier_data = non_outlier_data[~(
    filter_min|filter_max
    )]

# %%
non_outlier_data.head(5)
# Out:
#     school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 3        1    1   15        1        2        1     4     2     4     1  ...
# 5        1    2   16        1        1        1     4     3     1     5  ...
# 6        1    2   16        1        1        1     2     2     5     5  ...
# 9        1    2   15        1        2        1     3     4     5     5  ...
# 10       1    1   15        1        2        1     4     4     3     4  ...
#
#     famrel  freetime  goout  Dalc  Walc  health  absences  PreTest  Test  \
# 3        3         2      2     1     1       5         2       15    14
# 5        5         4      2     1     2       5        10       15    15
# 6        4         4      4     1     1       3         0       12    12
# 9        5         5      1     1     1       5         0       14    15
# 10       3         3      3     1     2       2         0       10     8
#
#     PostTest
# 3         15
# 5         15
# 6         11
# ...

# %%
non_outlier_data.shape
# Out:
# (98, 33)

# %%
correlation_between_columns = non_outlier_data[numeric_columns].corr()
upper_triangle_corr = np.triu(correlation_between_columns)

#mengecek homoskedastisitas
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(correlation_between_columns, annot = True, cmap="YlGnBu",ax=ax,annot_kws={"size":8},mask=upper_triangle_corr)

# %%
scatter_plot_between_target_feature = sns.pairplot(
    data=non_outlier_data,
    y_vars=['PostTest'],
    x_vars=numeric_columns,
    height= 10,
    kind='scatter'
    )

# %%
final_feature_column = ['PreTest','Test']
target_column = ['PostTest']
final_column = final_feature_column+target_column
final_data = non_outlier_data[final_column]

# %%
final_data.shape
# Out:
# (98, 3)

# %%
final_data.head(10)
# Out:
#     PreTest  Test  PostTest
# 3        15    14        15
# 5        15    15        15
# 6        12    12        11
# 9        14    15        15
# 10       10     8         9
# 11       10    12        12
# 12       14    14        14
# 13       10    10        11
# 15       14    14        14
# 16       13    14        14

# %%
final_feature_array = final_data[final_feature_column].to_numpy()
target_array = final_data[target_column].to_numpy()

# %%
print('shape of final feature:',final_feature_array.shape)
print('shape of target:',target_array.shape)
# Out:
# shape of final feature: (98, 2)
# shape of target: (98, 1)

# %%
import sklearn.model_selection as model_selection
# split the data into test and train
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    final_feature_array,
    target_array,
    train_size=0.8,
    random_state=0
    )

# %%
print('Shape Data X Train:')
print(X_train.shape)
print('\nShape Data X Test:')
print(X_test.shape)
print('\nShape Data y Train:')
print(y_train.shape)
print('\nShape Data y Test:')
print(y_test.shape)
# Out:
# Shape Data X Train:
# (78, 2)
#
# Shape Data X Test:
# (20, 2)
#
# Shape Data y Train:
# (78, 1)
#
# Shape Data y Test:
# (20, 1)

# %%
import sklearn.linear_model as linear_model
regression_model = linear_model.LinearRegression()

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# model result
print('Coefficients:\n',regression_model.coef_)
# print('\n')
print('Intercept:',regression_model.intercept_)
# Out:
# Coefficients:
#  [[0.39965498 0.76146997]]
# Intercept: [-2.16517379]

# %%
y_train_pred = regression_model.predict(X_train)
y_test_pred = regression_model.predict(X_test)
target_array_pred = regression_model.predict(final_feature_array)

# %%
print('Real Data')
print(y_train[:5])
print('\n Predicted Data')
print(y_train_pred[:5])
# Out:
# Real Data
# [[11]
#  [10]
#  [15]
#  [15]
#  [14]]
#
#  Predicted Data
# [[ 9.40823573]
#  [ 9.04642073]
#  [14.85204549]
#  [15.65135544]
#  [14.09057551]]

# %%
final_with_pred_data = final_data.copy()
final_with_pred_data['PostTest'] = target_array_pred.reshape(-1,)
final_with_pred_data.head(5)
# Out:
#     PreTest  Test   PostTest
# 3        15    14  14.490230
# 5        15    15  15.251700
# 6        12    12  11.768326
# 9        14    15  14.852045
# 10       10     8   7.923136

# %%
from sklearn.metrics import mean_squared_error
rmse_training = mean_squared_error(y_true=y_train,y_pred=y_train_pred,squared=False)
rmse_test = mean_squared_error(y_true=y_test,y_pred=y_test_pred,squared=False)

print('RMSE Training Data: {}'.format(rmse_training))
print('RMSE Test Data: {}'.format(rmse_test))
# Out:
# RMSE Training Data: 1.5080999108999307
# RMSE Test Data: 1.9523037486222836

# %%
print('R^2 score:',regression_model.score(X_train, y_train))
# Out:
# R^2 score: 0.8194326294993761

# %%
from scipy import stats
residual = (abs(target_array) - abs(target_array_pred))
sw = stats.shapiro(residual)
ks = stats.kstest(residual, 'norm')

print('Shapiro-Wilk test ---- statistic: {}, p-value: {}'.format(sw[0],sw[1]))
print('Kolmogorov-Smirnov test ---- statistic: {}, p-value: {}'.format(ks.statistic,ks.pvalue))
# Out:
# Shapiro-Wilk test ---- statistic: 0.6766422390937805, p-value: 2.22666503291169e-13
# Kolmogorov-Smirnov test ---- statistic: 1.0, p-value: 0.0

# %%
import statsmodels.api as sm
model = sm.OLS(y_train,X_train)
results = model.fit()
print(results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                              2588.
# Date:                Tue, 24 May 2022   Prob (F-statistic):                    1.26e-70
# Time:                        11:55:07   Log-Likelihood:                         -146.18
# No. Observations:                  78   AIC:                                      296.4
# Df Residuals:                      76   BIC:                                      301.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
